# %% [markdown]
# <a href="https://colab.research.google.com/github/SubashSankaralingam/Registration/blob/main/Copy_of_Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
df1 = pd.read_csv("/content/college_1.csv")
df2 = pd.read_csv("/content/college_2.csv")

# %%
df1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 79    KarthikeyanS    45.0    0.0                  0               0
# 80        BARATH.P    29.0    0.0                  0               0
# 81   N.Ajith kumar    82.0    0.0                  0               0
# 82    mohamed nabi     0.0    0.0                  0               0
# 83  yaser ahamed.A     0.0   27.0                  0               0
#
#                                 Department  Rising
# 0         Computer Science and Engineering       0
# ...

# %%
df2
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
DF = pd.concat([df1,df2])
DF
# Out:
#              Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0       A.Dharani    82.0   20.0              24500           24500
# 1     V.JEEVITHA     82.0   20.0              21740           21740
# 2     HEMAVATHI.R   100.0  100.0              19680           19680
# 3     Mugunthan S   100.0   47.0              10610           10610
# 4     Sathammai.S   100.0    8.0               8980            8980
# ..            ...     ...    ...                ...             ...
# 30  praveen raj j    24.0    0.0               2380            2380
# 31     AMARNATH D    -1.0   12.0               1890            1890
# 32           bala    32.0    0.0               1720            1720
# 33           XY Z    -1.0   -1.0                  0               0
# 34      Hariharan    -1.0   -1.0                  0               0
#
#                                    Department  Rising  python_en  \
# 0            Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)
#
# > Indented block

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
Ex1=df1[df1["CodeKata Score"]>15000]
Ex1.to_csv("1Exceeded expectations.csv")
Ex2=df2[df2["CodeKata Score"]>15000]
Ex2.to_csv("2Exceeded expectations.csv")
Ex=DF[DF["CodeKata Score"]>15000]
Ex.to_csv("Exceeded expectations.csv")

# %%
re1=df1[df1["CodeKata Score"].between(10000,15000)]
re1.to_csv("1Reached_expectations.csv")
re2=df2[df2["CodeKata Score"].between(10000,15000)]
re2.to_csv("2Reached_expectations.csv")
re=DF[DF["CodeKata Score"].between(10000,15000)]
re.to_csv("Reached_expectations.csv")

# %%
NI1=df1[df1["CodeKata Score"].between(7000,10000)]
NI1.to_csv("1Needs_Improvement.csv")
NI2=df2[df2["CodeKata Score"].between(7000,10000)]
NI2.to_csv("2Needs_Improvement.csv")
NI=DF[DF["CodeKata Score"].between(7000,10000)]
NI.to_csv("Needs_Improvement.csv")

# %%
US1=df1[df1["CodeKata Score"]<7000]
US1.to_csv("1Unsatisfactory.csv")
US2=df2[df2["CodeKata Score"]<7000]
US2.to_csv("2Unsatisfactory.csv")
US=DF[DF["CodeKata Score"]<7000]
US.to_csv("Unsatisfactory.csv")

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
PG_m=DF["Previous Geekions"].mean()
CS_m=DF["CodeKata Score"].mean()
PG_m
CS_m
# Out:
# 4051.764705882353

# %% [markdown]
# ###### No of students participated

# %%
No=DF[DF["CodeKata Score"]>0]
No.count()
# Out:
# Name                      112
# python                    112
# mysql                     112
# Previous Geekions         112
# CodeKata Score            112
# Department                112
# Rising                    112
# python_en                  33
# computational_thinking     33
# dtype: int64

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
Avg = DF[["python","python_en","mysql","computational_thinking"]].mean()
Avg
# Out:
# python                    54.352941
# python_en                 29.657143
# mysql                     23.500000
# computational_thinking     2.200000
# dtype: float64

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
RS=DF.sort_values(by=["Rising"],ascending=[False])
RS.head(3)
# Out:
#                  Name  python  mysql  Previous Geekions  CodeKata Score  \
# 8            shifak N    58.0    0.0               5180            8320
# 18     Narasimhan Y L    -1.0    0.0               4800            6800
# 2   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                 Department  Rising  python_en  \
# 8   Electronics and Electrical Engineering    3140        0.0
# 18        Computer Science and Engineering    2000       -1.0
# 2         Computer Science and Engineering    2000       55.0
#
#     computational_thinking
# 8                      0.0
# 18                     0.0
# 2                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
SS=DF.sort_values(by=["CodeKata Score"],ascending=[False])
SS.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
import plotly.express as px

# %%
fig=px.pie(values=DF["CodeKata Score"],names=DF["Department"])
fig.update_traces(textposition="inside")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
x=DF["Department"]
y=DF["CodeKata Score"]
plt.barh(x,y,height=0.5)
plt.xlabel("Codekata score")
plt.ylabel("Department")
plt.show()

# %%
fig=px.bar(DF,x="Department",y='CodeKata Score')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.histogram(x=DF["CodeKata Score"],color=DF["Department"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.sunburst(DF,path=["python","mysql"],values="CodeKata Score",color="Department")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
